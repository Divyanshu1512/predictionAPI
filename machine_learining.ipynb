# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\divya\OneDrive\Desktop\codes\dataset\babies.csv")
df.head()
# Out:
#    case  bwt  gestation  parity   age  height  weight  smoke
# 0     1  120      284.0       0  27.0    62.0   100.0    0.0
# 1     2  113      282.0       0  33.0    64.0   135.0    0.0
# 2     3  128      279.0       0  28.0    64.0   115.0    1.0
# 3     4  123        NaN       0  36.0    69.0   190.0    0.0
# 4     5  108      282.0       0  23.0    67.0   125.0    1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1236 entries, 0 to 1235
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   case       1236 non-null   int64
#  1   bwt        1236 non-null   int64
#  2   gestation  1223 non-null   float64
#  3   parity     1236 non-null   int64
#  4   age        1234 non-null   float64
#  5   height     1214 non-null   float64
#  6   weight     1200 non-null   float64
#  7   smoke      1226 non-null   float64
# dtypes: float64(5), int64(3)
# memory usage: 77.4 KB

# %%
df.describe()
# Out:
#               case          bwt    gestation       parity          age  \
# count  1236.000000  1236.000000  1223.000000  1236.000000  1234.000000
# mean    618.500000   119.576861   279.338512     0.254854    27.255267
# std     356.946775    18.236452    16.027693     0.435956     5.781405
# min       1.000000    55.000000   148.000000     0.000000    15.000000
# 25%     309.750000   108.750000   272.000000     0.000000    23.000000
# 50%     618.500000   120.000000   280.000000     0.000000    26.000000
# 75%     927.250000   131.000000   288.000000     1.000000    31.000000
# max    1236.000000   176.000000   353.000000     1.000000    45.000000
#
#             height       weight        smoke
# count  1214.000000  1200.000000  1226.000000
# mean     64.047776   128.625833     0.394780
# std       2.533409    20.971862     0.489003
# min      53.000000    87.000000     0.000000
# 25%      62.000000   114.750000     0.000000
# 50%      64.000000   125.000000     0.000000
# 75%      66.000000   139.000000     1.000000
# max      72.000000   250.000000     1.000000

# %% [markdown]
# lets clean the data

# %%
df.dropna(inplace=True)
df
# Out:
#       bwt  gestation  parity   age  height  weight  smoke
# 0     120      284.0       0  27.0    62.0   100.0    0.0
# 1     113      282.0       0  33.0    64.0   135.0    0.0
# 2     128      279.0       0  28.0    64.0   115.0    1.0
# 4     108      282.0       0  23.0    67.0   125.0    1.0
# 5     136      286.0       0  25.0    62.0    93.0    0.0
# ...   ...        ...     ...   ...     ...     ...    ...
# 1231  113      275.0       1  27.0    60.0   100.0    0.0
# 1232  128      265.0       0  24.0    67.0   120.0    0.0
# 1233  130      291.0       0  30.0    65.0   150.0    1.0
# 1234  125      281.0       1  21.0    65.0   110.0    0.0
# 1235  117      297.0       0  38.0    65.0   129.0    0.0
#
# [1174 rows x 7 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['bwt', 'gestation', 'parity', 'age', 'height', 'weight', 'smoke'], dtype='object')

# %%
df.drop(columns=['case'],inplace=True)

# %%
df.columns
# Out:
# Index(['bwt', 'gestation', 'parity', 'age', 'height', 'weight', 'smoke'], dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['gestation'],df['bwt'])
plt.legend()
plt.xlabel("gen")
plt.ylabel('weight')
plt.show()
# Out:
# C:\Users\divya\AppData\Local\Temp\ipykernel_40280\2860925600.py:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.scatter(df['weight'],df['bwt'])
plt.legend()
plt.xlabel("mother's weight")
plt.ylabel('weight')
plt.show()
# Out:
# C:\Users\divya\AppData\Local\Temp\ipykernel_14344\486124716.py:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.scatter(df['height'],df['bwt'])
plt.legend()
plt.xlabel("mother's height")
plt.ylabel('weight')
plt.show()
# Out:
# C:\Users\divya\AppData\Local\Temp\ipykernel_14344\1509591063.py:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df['smoke'].value_counts()
# Out:
# smoke
# 0.0    715
# 1.0    459
# Name: count, dtype: int64

# %%
df['smoke'].value_counts(normalize=True)*100
# Out:
# smoke
# 0.0    60.902896
# 1.0    39.097104
# Name: proportion, dtype: float64

# %%
df['parity'].value_counts()
# Out:
# parity
# 0    866
# 1    308
# Name: count, dtype: int64

# %%
y=df['bwt']
x=df.iloc[:,1:]
x.head()
# Out:
#    gestation  parity   age  height  weight  smoke
# 0      284.0       0  27.0    62.0   100.0    0.0
# 1      282.0       0  33.0    64.0   135.0    0.0
# 2      279.0       0  28.0    64.0   115.0    1.0
# 4      282.0       0  23.0    67.0   125.0    1.0
# 5      286.0       0  25.0    62.0    93.0    0.0

# %%
from sklearn.model_selection import train_test_split as tts
x_train,x_test,y_train,y_test=tts(x,y,test_size=0.20)

# %%
x_train.shape
# Out:
# (939, 6)

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge
lr=LinearRegression()
lasso=Lasso()
rigde=Ridge()

# %%
lr.fit(x_train,y_train)
lasso.fit(x_train,y_train)
rigde.fit(x_train,y_train)
# Out:
# Ridge()

# %%
lr_pred = lr.predict(x_test)
las_pred = lasso.predict(x_test)
rid_pred = rigde.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error

lr_rscore = r2_score(y_test, lr_pred)
las_rscore = r2_score(y_test, las_pred)
rid_rscore = r2_score(y_test, rid_pred)

# %%
lr_mse = mean_squared_error(y_test, lr_pred)
las_mse = mean_squared_error(y_test, las_pred)
rid_mse = mean_squared_error(y_test, rid_pred)

# %%
print("\nPerformance of Linear Regression Model :")
print("R2score : ",lr_rscore)
print("MSE : ",lr_mse)


print("\nPerformance of Lasso Regression Model :")
print("R2score : ",las_rscore)
print("MSE : ",las_mse)


print("\nPerformance of Ridge Regression Model :")
print("R2score : ",rid_rscore)
print("MSE : ",rid_mse)
# Out:
# Performance of Linear Regression Model :
# R2score :  0.24976232959624156
# MSE :  245.89529051051792
#
# Performance of Lasso Regression Model :
# R2score :  0.24331056555726227
# MSE :  248.00989826117424
#
# Performance of Ridge Regression Model :
# R2score :  0.24988862894863217
# MSE :  245.85389507388157

# %%
import pickle
with open(r"C:\Users\divya\OneDrive\Desktop\codes\model\model.pkl",'wb') as f:
    pickle.dump(lr,f)

# %%
with open (r'C:\Users\divya\OneDrive\Desktop\codes\model\model.pkl','rb') as obj:
    mymodel=pickle.load(obj)

# %%
x_train.head()
# Out:
#       gestation  parity   age  height  weight  smoke
# 456       262.0       1  32.0    64.0   125.0    0.0
# 588       283.0       0  22.0    65.0   119.0    0.0
# 751       277.0       0  35.0    63.0   140.0    0.0
# 1102      272.0       1  35.0    61.0   120.0    1.0
# 798       269.0       1  21.0    64.0   149.0    1.0

# %%
test_data = {
    "gestation":[302.0],	
    "parity" : [1]	,
    "age":[22.0],
    "height":[70.0],	
    "weight":[170.0],
    "smoke":[1.0]
}

# %%
df1=pd.DataFrame(test_data)

# %%
df1
# Out:
#    gestation  parity   age  height  weight  smoke
# 0      302.0       1  22.0    70.0   170.0    1.0

# %%
mymodel.predict(df1)
# Out:
# array([132.39867304])
